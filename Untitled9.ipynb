# %%
def return_all_company_id_list(number=1):
    import requests
    import json
    import pandas as pd

    http_proxy  = "http://165.225.72.41:10792"
    https_proxy = "https://185.46.214.34:10792"
    ftp_proxy   = ""

    proxyDict = { 
                  "http"  : http_proxy, 
                  "https" : https_proxy, 
                  "ftp"   : ftp_proxy
                }
    url = 'http://www.registeruz.sk/cruz-public/api/uctovne-jednotky?zmenene-od=2000-01-01&pokracovat-za-id='+str(number)+'&max-zaznamov=1&pravna-forma=112'
    #print(url)
    r = requests.get(url, proxies=proxyDict)
    res=json.loads(r.content.decode("utf-8"))
    print(r.status_code , (res['id'][0]))
    
    if not res['id'][0]:
        print("Error first value not find")
        
    else:
        #print("else")
        #A.append(res['id'][0])
        number = (res['id'][0])
        #print(A)
        return  res['id'][0]

# %%
A=[return_all_company_id_list()]

for all in A :
    
    A.append(return_all_company_id_list(A[-1]))

# %%
print(A)

# %%
def return_id_details(number=1):
    import requests
    import json
    import pandas as pd

    http_proxy  = "http://165.225.72.41:10792"
    https_proxy = "https://185.46.214.34:10792"
    ftp_proxy   = ""

    proxyDict = { 
                  "http"  : http_proxy, 
                  "https" : https_proxy, 
                  "ftp"   : ftp_proxy
    }
    
    try:
        url = 'http://www.registeruz.sk/cruz-public/api/uctovna-jednotka?id='+str(number)
        r = requests.get(url, proxies=proxyDict)
        res=json.loads(r.content.decode("utf-8"))
        return  res
    except :
        print("Error occured")
        pass
    #url = 'http://www.registeruz.sk/cruz-public/api/uctovna-jednotka?id='+str(number)
    #print(url)
    
    '''
    if not res['id'][0]:
        print("Error first value not find")
        
    else:
        #print("else")
        #A.append(res['id'][0])
        number = (res['id'][0])
        #print(A)
        return  res['id'][0]
        
    '''

# %%
type(return_id_details())
# Out:
# dict

# %%
A = [  return_id_details().keys()]

# %%
len(A[0]
   )
# Out:
# 19

# %%
import pandas as pd

# %%
df = pd.DataFrame()

for x in range(1,2001):
    
    df = pd.concat([df , pd.DataFrame.from_dict(return_id_details(x), orient='index', dtype=None) ], axis=1 ,ignore_index=True )

df.to_csv('firmy.csv')

# %%
df.ix['datumZalozenia']
# Out:
# 0       1990-06-28
# 1       1992-11-17
# 2       1990-10-01
# 3       1991-01-17
# 4       1990-07-01
# 5       1990-09-01
# 6       1990-09-24
# 7       1992-03-12
# 8       1979-11-01
# 9       1989-11-20
# 10      1992-10-22
# 11      1991-10-30
# 12      1992-09-16
# 13      1989-10-11
# 14      1991-02-13
# 15      2014-07-01
# 16      1990-09-01
# 17      1991-01-01
# 18      1990-08-30
# 19      1990-12-17
# 20      1990-07-23
# 21      1982-11-01
# 22      1993-01-01
# 23      1990-06-01
# 24      1990-05-28
# 25      1991-02-18
# 26      1992-12-02
# 27      1982-09-01
# 28      1990-05-01
# 29      1990-09-01
#            ...
# 1970    1990-01-01
# 1971    1990-11-01
# 1972    1973-07-01
# 1973    1990-08-27
# 1974    1973-07-01
# 1975    1978-08-01
# 1976    1992-11-17
# 1977    1991-04-22
# 1978    1991-01-28
# 1979    1990-05-01
# 1980    1991-05-22
# 1981    1990-09-15
# 1982    1990-07-13
# 1983    1991-01-02
# 1984    1991-12-10
# 1985    1990-10-14
# ...

# %%
A=[]

for a in range(0,df.shape[1]):
    
    A.append(df[a]['datumZalozenia'])

# %%
date= pd.to_datetime(A)

# %%
A[:5]
# Out:
# ['1990-06-28', '1992-11-17', '1990-10-01', '1991-01-17', '1990-07-01']

# %%
# %matplotlib nbagg

import matplotlib.pyplot as plt

# %%
time_series = pd.DataFrame(pd.to_datetime(df.ix['datumZalozenia']).value_counts().reset_index())
time_series.columns = ['date', 'count']

# %%
time_series['count'].sum()
# Out:
# 2000

# %%
import datetime as dt

a =time_series['count'].groupby(time_series['date'].dt.year).sum()
a.plot(kind="bar")
print(a.max())
a.cumsum()
# Out:
# <img src="data:image/png;base64,..." width="639.0476480687299">
# 877
# date
# 1953       2
# 1971       3
# 1972       7
# 1973     163
# 1974     175
# 1975     176
# 1976     213
# 1977     219
# 1978     226
# 1979     230
# 1980     232
# 1981     237
# 1982     250
# 1983     251
# 1984     253
# 1985     264
# 1986     294
# 1987     297
# 1988     303
# 1989     337
# 1990    1214
# 1991    1611
# 1992    1885
# 1993    1940
# 1994    1949
# 1995    1954
# 1996    1960
# 1997    1962
# 2010    1967
# 2011    1970
# 2012    1978
# 2013    1987
# 2014    1991
# 2015    1994
# 2016    1998
# 2017    1999
# 2018    2000
# Name: count, dtype: int64
