# %%
import requests

http_proxy  = "http://165.225.72.41:10792"
https_proxy = "https://185.46.214.34:10792"
ftp_proxy   = "ftp://10.10.1.10:3128"

proxyDict = { 
              "http"  : http_proxy, 
              "https" : https_proxy, 
              "ftp"   : ftp_proxy
            }

r = requests.get('http://www.registeruz.sk/cruz-public/api/pravne-formy', proxies=proxyDict)
#print(data["ico"])
data = r.json()

#print(data)

print(len(data['klasifikacie']))
#print(len(data['klasifikacie'][0]))
data['klasifikacie'][1]['kod']

for i in range(len(data['klasifikacie'])):
    
        b=(data['klasifikacie'][i]['kod'])
        a=(data['klasifikacie'][i]['nazov']['sk']) 
        print("{}:{} {}".format(i,b,a))
# Out:
# 103
# 0:000 Zatiaľ neurčené
# 1:100 FO v RDIS
# 2:101 Živnostník
# 3:102 Živnostník v OR
# 4:103 SHR roľník
# 5:104 SHR roľník v OR
# 6:105 FO-slob.povolanie
# 7:106 FO-slob.povolanie v OR
# 8:107 Živ. a SHR roľník
# 9:108 Živ. a SHR roľník v OR
# 10:109 Živ.a sl.povolanie
# 11:110 Živ.a sl.povolanie v OR
# 12:111 Ver. obch. spol.
# 13:112 Spol. s r. o.
# 14:113 Kom. spol.
# 15:114 Spol. kom. na akcie
# 16:115 Spoločný podnik
# 17:116 Záujmové združenie
# 18:117 Nadácia
# 19:118 Neinvestičný fond
# 20:119 Nezisková organizácia
# 21:121 Akc. spol.
# 22:122 Európ.zoskup.hosp.záujm.
# 23:123 Európska spoločnosť
# 24:124 Európske družstvo
# 25:131 Svojpomoc.poľn.družstvo
# 26:201 Poľnohospodár.družstvo
# 27:205 Družstvo
# 28:211 Družstevný podnik poľ.
# 29:231 Družstvo výrobné
# 30:232 Družstvo spotrebné
# 31:233 Družstvo bytové
# 32:234 Družstvo iné
# 33:241 Družstevný podnik
# 34:242 Spoločný podnik
# 35:251 Záujmová org.družstiev
# 36:261 Spoločná záuj.org.druž.
# ...
